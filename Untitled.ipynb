# %%
import tensorflow as tf
import numpy as np
import cv2
import random
import sys
from keras.preprocessing import image

# %%
def setParams(ss,args):
    if args["method"] == "fast":
        print("[INFO] using *fast* selective search")
        ss.switchToSelectiveSearchFast()
    else:
        print("[INFO] using *quality* selective search")
        ss.switchToSelectiveSearchQuality()

# %%
args={"method":"fast"}
image = cv2.imread("cars.jpg")
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
ss.setBaseImage(image)
setParams(ss,args)
# Out:
# [INFO] using *fast* selective search

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
model = VGG16(weights="imagenet")

# %%
def preprocessImg(img):
    image = cv2.resize(img, (224, 224))   
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    image = preprocess_input(image)
    return image

# %%
rects = ss.process()

numShowRects = 100
    # increment to increase/decrease total number
    # of reason proposals to be shown
increment = 50

while True:
    # create a copy of original image
    imOut = image.copy()

    # itereate over all the region proposals
    for i, rect in enumerate(rects):
        # draw rectangle for region proposal till numShowRects
        
        x, y, w, h = rect
        trgt=image[y:y+h,x:x+w]
        cv2.imwrite("target.jpg",trgt)
        trgt=preprocessImg(trgt)
        pred = model.predict(trgt)
        l = decode_predictions(pred)
        l = l[0][0]
        print('%s (%.2f%%)' % (l[1], l[2]*100))
        if(l[2]>=90):
            cv2.rectangle(imOut, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
        
        

    # show output
    cv2.imshow("Output", imOut)

    # record key press
    k = cv2.waitKey(0) & 0xFF

    # m is pressed
    if k == 109:
        # increase total number of rectangles to show by increment
        numShowRects += increment
    # l is pressed
    elif k == 108 and numShowRects > increment:
        # decrease total number of rectangles to show by increment
        numShowRects -= increment
    # q is pressed
    elif k == 113:
        break
# close image show window
cv2.destroyAllWindows()
# Out:
# cocktail_shaker (25.67%)
# lipstick (2.40%)
# radiator (7.68%)
# oil_filter (12.61%)
# shower_curtain (23.19%)
# theater_curtain (25.95%)
# combination_lock (15.70%)
# hair_spray (6.42%)
# grille (19.31%)
# moving_van (20.94%)
# cleaver (9.12%)
# soap_dispenser (5.78%)
# Windsor_tie (16.42%)
# shower_curtain (12.18%)
# racer (23.95%)
# loudspeaker (15.24%)
# desktop_computer (4.79%)
# cleaver (1.94%)
# modem (8.98%)
# milk_can (7.40%)
# space_heater (43.11%)
# trailer_truck (31.78%)
# abaya (23.51%)
# fire_screen (18.93%)
# fire_screen (14.47%)
# theater_curtain (15.11%)
# dumbbell (25.16%)
# space_heater (28.01%)
# moving_van (28.47%)
# digital_watch (78.08%)
# racer (9.08%)
# combination_lock (14.85%)
# nematode (4.25%)
# prison (11.08%)
# racer (19.32%)
# hatchet (3.45%)
# loudspeaker (7.74%)
# cocktail_shaker (41.14%)
# Windsor_tie (14.17%)
# abaya (9.46%)
# cleaver (1.98%)
# milk_can (11.96%)
# matchstick (4.53%)
# milk_can (10.52%)
# cocktail_shaker (17.63%)
# printer (19.05%)
# cocktail_shaker (39.60%)
# cocktail_shaker (28.31%)
# velvet (47.71%)
# cleaver (6.37%)
# moving_van (33.04%)
# shoji (9.74%)
# trailer_truck (11.82%)
# cleaver (26.98%)
# moving_van (18.66%)
# shower_curtain (6.56%)
# switch (10.44%)
# cocktail_shaker (87.45%)
# window_shade (8.03%)
# digital_watch (24.30%)
# cleaver (8.52%)
# nematode (44.35%)
# Windsor_tie (21.15%)
# wall_clock (2.44%)
# cleaver (29.96%)
# waffle_iron (32.51%)
# Windsor_tie (13.99%)
# space_bar (16.92%)
# reel (8.81%)
# cleaver (13.89%)
# theater_curtain (21.35%)
# printer (26.75%)
# convertible (7.41%)
# combination_lock (10.93%)
# shower_curtain (18.72%)
# cleaver (11.86%)
# theater_curtain (8.44%)
# cleaver (3.95%)
# reflex_camera (10.79%)
# mailbag (25.40%)
# limousine (6.45%)
# sports_car (27.99%)
# abaya (4.56%)
# soap_dispenser (12.10%)
# minivan (15.68%)
# digital_watch (22.17%)
# mailbag (20.82%)
# cleaver (1.79%)
# theater_curtain (5.52%)
# cleaver (10.45%)
# abaya (9.50%)
# hourglass (18.69%)
# dumbbell (14.09%)
# moving_van (36.16%)
# radiator (17.34%)
# limousine (19.73%)
# modem (5.51%)
# reel (19.10%)
# digital_watch (16.14%)
# cleaver (2.56%)
# Japanese_spaniel (10.35%)
# toaster (14.48%)
# abaya (16.66%)
# radiator (10.66%)
# oil_filter (15.34%)
# ice_bear (3.89%)
# bulletproof_vest (9.21%)
# space_heater (64.29%)
# nematode (15.20%)
# sports_car (44.40%)
# lens_cap (6.59%)
# moving_van (27.86%)
# slide_rule (58.78%)
# cleaver (2.09%)
# plunger (3.02%)
# sports_car (42.55%)
# letter_opener (9.68%)
# cassette_player (31.87%)
# reel (26.87%)
# milk_can (17.66%)
# combination_lock (14.23%)
# sports_car (29.13%)
# moving_van (61.34%)
# grille (15.87%)
# toaster (4.68%)
# soap_dispenser (10.20%)
# theater_curtain (61.30%)
# milk_can (16.51%)
# radiator (13.20%)
# cocktail_shaker (48.09%)
# cocktail_shaker (27.06%)
# combination_lock (27.99%)
# matchstick (6.67%)
# space_heater (45.96%)
# cassette_player (52.66%)
# digital_watch (16.39%)
# shower_curtain (32.98%)
# fire_screen (30.37%)
# theater_curtain (62.90%)
# shower_curtain (10.26%)
# sports_car (26.94%)
# reel (9.66%)
# fire_screen (18.57%)
# loudspeaker (7.72%)
# nematode (5.63%)
# minibus (28.52%)
# space_heater (5.17%)
# revolver (4.10%)
# pedestal (16.00%)
# cocktail_shaker (61.77%)
# matchstick (4.60%)
# hourglass (11.47%)
# cassette_player (8.15%)
# combination_lock (5.66%)
# mousetrap (6.97%)
# reel (16.46%)
# moving_van (22.60%)
# Japanese_spaniel (7.36%)
# liner (6.91%)
# theater_curtain (13.66%)
# milk_can (3.17%)
# whiskey_jug (11.17%)
# can_opener (7.57%)
# espresso_maker (12.63%)
# cleaver (2.54%)
# cleaver (13.23%)
# theater_curtain (30.27%)
# sports_car (9.29%)
# Japanese_spaniel (8.16%)
# cocktail_shaker (4.92%)
# cassette_player (12.45%)
# combination_lock (17.12%)
# punching_bag (3.40%)
# theater_curtain (38.39%)
# coffee_mug (5.04%)
# combination_lock (12.83%)
# cleaver (1.87%)
# shower_curtain (9.67%)
# studio_couch (13.97%)
# space_heater (48.34%)
# spotlight (3.09%)
# safety_pin (10.54%)
# space_heater (80.90%)
# sandal (6.08%)
# matchstick (5.03%)
# radiator (7.36%)
# sports_car (12.05%)
# cocktail_shaker (3.88%)
# minibus (25.89%)
# Windsor_tie (11.67%)
# digital_watch (84.17%)
# cleaver (4.37%)
# reflex_camera (22.35%)
# theater_curtain (53.03%)
# hair_spray (3.96%)
# dumbbell (32.18%)
# toaster (48.06%)
# digital_watch (28.69%)
# digital_watch (74.67%)
# minivan (40.40%)
# dumbbell (23.47%)
# theater_curtain (14.02%)
# Windsor_tie (24.42%)
# abaya (10.93%)
# moving_van (22.59%)
# knee_pad (8.73%)
# abaya (6.85%)
# cleaver (1.85%)
# minibus (23.75%)
# theater_curtain (83.13%)
# moving_van (19.57%)
# pedestal (27.55%)
# oil_filter (11.17%)
# fire_screen (8.30%)
# Windsor_tie (6.17%)
# cellular_telephone (14.36%)
# moving_van (47.28%)
# sports_car (19.12%)
# cocktail_shaker (59.97%)
# cleaver (9.98%)
# abaya (40.41%)
# cocktail_shaker (23.15%)
# cassette_player (12.31%)
# digital_watch (9.53%)
# abaya (5.19%)
# moving_van (22.38%)
# space_heater (27.27%)
# milk_can (5.65%)
# digital_watch (57.38%)
# shower_curtain (5.02%)
# cleaver (2.91%)
# moving_van (30.37%)
# combination_lock (7.66%)
# frying_pan (7.26%)
# grille (41.04%)
# cocktail_shaker (55.07%)
# theater_curtain (7.12%)
# hair_spray (4.91%)
# digital_watch (16.81%)
# bulletproof_vest (14.17%)
# sports_car (16.86%)
# reel (15.08%)
# Windsor_tie (15.69%)
# mousetrap (8.13%)
# nematode (65.22%)
# cocktail_shaker (18.30%)
# abaya (32.16%)
# theater_curtain (36.92%)
# black_grouse (2.58%)
# grille (52.16%)
# loudspeaker (3.13%)
# digital_watch (24.25%)
# dumbbell (67.95%)
# sports_car (35.04%)
# loudspeaker (2.98%)
# dumbbell (21.21%)
# Windsor_tie (35.55%)
# limousine (30.61%)
# spotlight (18.31%)
# loudspeaker (4.66%)
# abaya (7.65%)
# trailer_truck (33.68%)
# milk_can (15.66%)
# loudspeaker (9.95%)
# shower_curtain (30.84%)
# toaster (12.81%)
# matchstick (5.10%)
# cocktail_shaker (56.28%)
# modem (9.38%)
# acoustic_guitar (9.93%)
# limousine (29.48%)
# moving_van (24.97%)
# liner (7.79%)
# waffle_iron (30.94%)
# car_wheel (26.59%)
# theater_curtain (65.74%)
# sports_car (24.79%)
# nematode (44.15%)
# grand_piano (17.85%)
# hair_spray (7.15%)
# hair_spray (14.45%)
# moving_van (20.24%)
# racer (14.00%)
# loudspeaker (11.99%)
# theater_curtain (45.66%)
# cleaver (1.82%)
# radiator (13.64%)
# moving_van (62.58%)
# mousetrap (9.99%)
# milk_can (4.04%)
# cleaver (1.90%)
# waffle_iron (49.55%)
# mousetrap (6.91%)
# can_opener (7.48%)
# grille (20.85%)
# window_shade (20.18%)
# spotlight (4.32%)
# cocktail_shaker (6.06%)
# digital_watch (18.23%)
# sports_car (16.95%)
# loudspeaker (2.87%)
# oil_filter (24.85%)
# plate_rack (13.85%)
# combination_lock (5.74%)
# loudspeaker (2.91%)
# abaya (5.33%)
# hair_spray (9.89%)
# limousine (24.86%)
# dumbbell (12.37%)
# cleaver (17.17%)
# suit (4.85%)
# binder (11.04%)
# theater_curtain (60.12%)
# nematode (5.52%)
# digital_watch (32.86%)
# space_heater (33.57%)
# mailbox (33.30%)
# space_heater (25.22%)
# spotlight (20.06%)
# cassette_player (13.79%)
# space_heater (43.06%)
# moving_van (25.47%)
# theater_curtain (71.05%)
# pedestal (20.94%)
# dumbbell (47.34%)
# sports_car (27.49%)
# theater_curtain (74.00%)
# cocktail_shaker (9.60%)
# theater_curtain (36.72%)
# dumbbell (38.21%)
# trailer_truck (21.94%)
# sports_car (20.14%)
# spotlight (9.82%)
# computer_keyboard (7.62%)
# shoji (10.00%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17040/4098699857.py in <module>
#      18         cv2.imwrite("target.jpg",trgt)
#      19         trgt=preprocessImg(trgt)
# ---> 20         pred = model.predict(trgt)
#      21         l = decode_predictions(pred)
#      22         l = l[0][0]
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1787           for step in data_handler.steps():
#    1788             callbacks.on_predict_batch_begin(step)
# -> 1789             tmp_batch_outputs = self.predict_function(iterator)
#    1790             if data_handler.should_sync:
#    1791               context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     947       # In this case we have not created variables on the first call. So we can
#     948       # run the first trace but we should fail if variables are created.
# --> 949       results = self._stateful_fn(*args, **kwds)
#     950       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     951         raise ValueError("Creating variables on a non-first call to a function"
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
